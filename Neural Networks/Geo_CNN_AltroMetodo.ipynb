# %% [markdown]
# <a href="https://colab.research.google.com/github/napolitanodst/Apprenticeship-log/blob/Apprenticeship-Code/Geo_CNN_AltroMetodo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt
import pickle
import zipfile
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Importing delle immagini del dataset
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/dataset.zip', 'r') 
zip_ref.extractall('/tmp') 
zip_ref.close()

# %%
Dir= '/tmp/dataset'
Classes= ['Metamorfiche', 'Vulcaniche', 'Sedimentarie']

# %%
data = []
for category in Classes:
    folder = os.path.join(Dir, category)
    label = Classes.index(category)
    for img in os.listdir(folder):
        percorso = os.path.join(folder, img)
        array = cv2.imread(percorso)
        array= cv2.resize(array,(384,306))
        data.append([array,label])
random.shuffle(data)

# %%
Test_data = []
Test_labels = []
for features, labels in data:
  Test_data.append(features)
  Test_labels.append(labels)

Data = np.array(Test_data)
Labels = np.array(Test_labels)

# %%
# Modello
model = tf.keras.models.Sequential(
    [
    tf.keras.layers.Rescaling(1./255),   
    tf.keras.layers.Conv2D(16, 4, activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(7, 4, activation ='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(len(Classes), activation="softmax")
    ]
)

# %%
# Modello
training=model.compile(
             optimizer=tf.keras.optimizers.Adam(),
             loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             metrics=["accuracy"]
)

# %%
# Early Stopping per monitorare la validation accuracy
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_accuracy',patience=10)

# %%
#Fitting
history = model.fit(
                    Data,
                    Labels,
                    validation_split = 0.3,
                    epochs=100,
                    callbacks= [early_stopping]
)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 13s 209ms/step - loss: 2.1286 - accuracy: 0.3946 - val_loss: 1.4613 - val_accuracy: 0.4127
# Epoch 2/100
# 5/5 [==============================] - 0s 55ms/step - loss: 1.1059 - accuracy: 0.5170 - val_loss: 1.0603 - val_accuracy: 0.4762
# Epoch 3/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.9485 - accuracy: 0.6122 - val_loss: 0.9110 - val_accuracy: 0.6190
# Epoch 4/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.6364 - accuracy: 0.8367 - val_loss: 0.6441 - val_accuracy: 0.7143
# Epoch 5/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.3373 - accuracy: 0.9252 - val_loss: 0.5055 - val_accuracy: 0.7460
# Epoch 6/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.1527 - accuracy: 0.9728 - val_loss: 0.5197 - val_accuracy: 0.7460
# Epoch 7/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0583 - accuracy: 1.0000 - val_loss: 0.5557 - val_accuracy: 0.7778
# Epoch 8/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0433 - accuracy: 0.9932 - val_loss: 0.5715 - val_accuracy: 0.7302
# Epoch 9/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0635 - accuracy: 0.9864 - val_loss: 0.4544 - val_accuracy: 0.7937
# Epoch 10/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.6944 - val_accuracy: 0.7143
# Epoch 11/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.5505 - val_accuracy: 0.7937
# Epoch 12/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.7611 - val_accuracy: 0.7302
# Epoch 13/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5344 - val_accuracy: 0.7778
# Epoch 14/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4718 - val_accuracy: 0.8413
# Epoch 15/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.4651 - val_accuracy: 0.8254
# Epoch 16/100
# 5/5 [==============================] - 0s 71ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.4728 - val_accuracy: 0.8254
# Epoch 17/100
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4930 - val_accuracy: 0.8095
# Epoch 18/100
# 5/5 [==============================] - 0s 66ms/step - loss: 7.5325e-04 - accuracy: 1.0000 - val_loss: 0.4992 - val_accuracy: 0.7937
# Epoch 19/100
# 5/5 [==============================] - 0s 71ms/step - loss: 5.2964e-04 - accuracy: 1.0000 - val_loss: 0.5091 - val_accuracy: 0.8095
# Epoch 20/100
# 5/5 [==============================] - 0s 66ms/step - loss: 4.6464e-04 - accuracy: 1.0000 - val_loss: 0.5167 - val_accuracy: 0.8254
# Epoch 21/100
# 5/5 [==============================] - 0s 72ms/step - loss: 4.2195e-04 - accuracy: 1.0000 - val_loss: 0.5245 - val_accuracy: 0.8254
# Epoch 22/100
# 5/5 [==============================] - 0s 61ms/step - loss: 3.8525e-04 - accuracy: 1.0000 - val_loss: 0.5302 - val_accuracy: 0.8095
# Epoch 23/100
# 5/5 [==============================] - 0s 66ms/step - loss: 3.4637e-04 - accuracy: 1.0000 - val_loss: 0.5297 - val_accuracy: 0.8095
# Epoch 24/100
# 5/5 [==============================] - 0s 62ms/step - loss: 3.2164e-04 - accuracy: 1.0000 - val_loss: 0.5256 - val_accuracy: 0.8095

# %%
#Plot di accuracy e validation accuracy
pd.DataFrame(history.history)[["accuracy","val_accuracy"]].plot()
# Out:
# <Axes: >

# %%
#Plot loss e validation loss
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
# Out:
# <Axes: >

# %%
#Confusion Matrix
predict= model.predict(Data)
predict1 = tf.argmax(predict, axis=1)
confusion_matrix(Labels,predict1)
# Out:
# 7/7 [==============================] - 0s 26ms/step
# array([[65,  3,  0],
#        [ 7, 58,  1],
#        [ 1,  0, 75]])

# %%
ConfusionMatrixDisplay.from_predictions(Labels, predict1)

# %%
def plot_wrong_labeled_data(X_test, y_true, y_preds, label_to_check, wrong_label = None):
  # Search for the wrong data
  wrongs = []
  for i in range(len(X_test)):
    true_label_found = y_true[i] == label_to_check
    wrong_label_found = wrong_label != None and y_preds[i] == wrong_label
    wrong_preds_label = wrong_label == None and y_preds[i] != label_to_check
    if true_label_found and (wrong_label_found or wrong_preds_label):
      wrongs.append((X_test[i], y_preds[i]))
  
  # Shuffle result
  random.shuffle(wrongs)

  # Plot result
  plt.figure(figsize=(10,10))
  for i in range(25):
    wrong = wrongs[i]
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(wrong[0], cmap=plt.cm.binary)
    plt.text(14, 32, wrong[1].numpy())
  plt.show()

# %%
#Plot immagini con wrong label
plot_wrong_labeled_data(Data, Labels, predict1, 1, 0)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-486d7b5cfd3c> in <module>
#       1 #Plot immagini con wrong label
# ----> 2 plot_wrong_labeled_data(Data, Labels, predict1, 1, 0)
#
# <ipython-input-17-c9d739a1cfc9> in plot_wrong_labeled_data(X_test, y_true, y_preds, label_to_check, wrong_label)
#      15   plt.figure(figsize=(10,10))
#      16   for i in range(50):
# ---> 17     wrong = wrongs[i]
#      18     plt.subplot(5, 5, i+1)
#      19     plt.xticks([])
#
# IndexError: list index out of range
