# %% [markdown]
# <a href="https://colab.research.google.com/github/napolitanodst/Apprenticeship-log/blob/Apprenticeship-Code/kFoldFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt
import pickle
import zipfile
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# %%
#Importing delle immagini del dataset
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/dataset.zip', 'r') 
zip_ref.extractall('/tmp') 
zip_ref.close()

# %%
Dir= '/tmp/dataset'
Classes= ['Metamorphic','Sedimentary', 'Volcanic']

# %%
data = []
for category in Classes:
    folder = os.path.join(Dir, category)
    label = Classes.index(category)
    for img in os.listdir(folder):
        percorso = os.path.join(folder, img)
        array = cv2.imread(percorso)
        array= cv2.resize(array,(384,306))
        data.append([array,label])
random.shuffle(data)

# %%
#Creazione Dataset
Train_data = []
Train_labels = []
for features, labels in data:
  Train_data.append(features)
  Train_labels.append(labels)

Data = np.array(Train_data)
Labels = np.array(Train_labels)

# %%
#Creazione Test Dataset
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/test.zip', 'r') 
zip_ref.extractall('/tmp') 
zip_ref.close()

cartella = '/tmp/test'
Test= []
for category in Classes:
    folder2 = os.path.join(cartella, category)
    label = Classes.index(category)
    for img in os.listdir(folder2):
        percorso2 = os.path.join(folder2, img)
        array2 = cv2.imread(percorso2)
        array2= cv2.resize(array2,(384,306))
        Test.append([array2,label])
random.shuffle(Test)     

Test_data = []
Test_labels = []
for features, labels in Test:
  Test_data.append(features)
  Test_labels.append(labels)

Test = np.array(Test_data)
Test_Labels = np.array(Test_labels)

# %%
#Early Stopping per monitorare la validation accuracy
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_accuracy',patience=10, mode="auto")

# %%
# K-fold Cross Validation model evaluation
n_folders = 3
kfold = KFold(n_splits=n_folders, shuffle=True)
folder_accuracy = []
folder_loss = []
inputs = np.concatenate((Data,Test), axis=0)
targets = np.concatenate((Labels,Test_Labels), axis=0)

fold_no=1
for train, test in kfold.split(inputs, targets):
    model = tf.keras.models.Sequential(  
        [
        tf.keras.layers.Rescaling(1./255),   
        tf.keras.layers.Conv2D(16, 4, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(7, 4, activation ='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(100, activation='relu'),
        tf.keras.layers.Dense(len(Classes), activation="softmax")
        ]
    )
    training=model.compile(
             optimizer=tf.keras.optimizers.Adam(),
             loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             metrics=["accuracy"]
    )
    history = model.fit(
                    Data,
                    Labels,
                    validation_split = 0.3,
                    epochs=100,
                    callbacks= [early_stopping]
    ) 
    scores = model.evaluate(inputs[test], targets[test], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    folder_accuracy.append(scores[1] * 100)
    folder_loss.append(scores[0])

    fold_no = fold_no + 1

print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(folder_accuracy)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {folder_loss[i]} - Accuracy: {folder_accuracy[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(folder_accuracy)} (+- {np.std(folder_accuracy)})')
print(f'> Loss: {np.mean(folder_loss)}')
print('------------------------------------------------------------------------')
# Out:
# Epoch 1/100
# 5/5 [==============================] - 13s 377ms/step - loss: 2.3746 - accuracy: 0.3878 - val_loss: 0.9741 - val_accuracy: 0.4127
# Epoch 2/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.9986 - accuracy: 0.3401 - val_loss: 0.9533 - val_accuracy: 0.4286
# Epoch 3/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.8681 - accuracy: 0.4694 - val_loss: 0.7578 - val_accuracy: 0.6508
# Epoch 4/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.5826 - accuracy: 0.8163 - val_loss: 1.0250 - val_accuracy: 0.5556
# Epoch 5/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.5594 - accuracy: 0.7483 - val_loss: 0.6978 - val_accuracy: 0.6032
# Epoch 6/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.3027 - accuracy: 0.9388 - val_loss: 0.5549 - val_accuracy: 0.7302
# Epoch 7/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.2346 - accuracy: 0.9252 - val_loss: 0.7060 - val_accuracy: 0.6032
# Epoch 8/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1260 - accuracy: 0.9660 - val_loss: 0.4630 - val_accuracy: 0.7460
# Epoch 9/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.1083 - accuracy: 0.9728 - val_loss: 1.0085 - val_accuracy: 0.6190
# Epoch 10/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0552 - accuracy: 0.9932 - val_loss: 0.4614 - val_accuracy: 0.7778
# Epoch 11/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0345 - accuracy: 1.0000 - val_loss: 0.8703 - val_accuracy: 0.6190
# Epoch 12/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0273 - accuracy: 1.0000 - val_loss: 0.4032 - val_accuracy: 0.8095
# Epoch 13/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.3634 - val_accuracy: 0.8571
# Epoch 14/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.7808 - val_accuracy: 0.6667
# Epoch 15/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.7020 - val_accuracy: 0.6984
# Epoch 16/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3751 - val_accuracy: 0.8095
# Epoch 17/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.3805 - val_accuracy: 0.7937
# Epoch 18/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.5804 - val_accuracy: 0.7302
# Epoch 19/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.7013 - val_accuracy: 0.7143
# Epoch 20/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5912 - val_accuracy: 0.7302
# Epoch 21/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4924 - val_accuracy: 0.7937
# Epoch 22/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.4808 - val_accuracy: 0.7937
# Epoch 23/100
# 5/5 [==============================] - 0s 49ms/step - loss: 9.7367e-04 - accuracy: 1.0000 - val_loss: 0.5701 - val_accuracy: 0.7302
# Score for fold 1: loss of 0.11683857440948486; accuracy of 94.52054500579834%
# Epoch 1/100
# 5/5 [==============================] - 2s 94ms/step - loss: 2.9385 - accuracy: 0.3605 - val_loss: 1.8611 - val_accuracy: 0.4127
# Epoch 2/100
# 5/5 [==============================] - 0s 58ms/step - loss: 1.0932 - accuracy: 0.6054 - val_loss: 0.7343 - val_accuracy: 0.6190
# Epoch 3/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.6759 - accuracy: 0.7279 - val_loss: 0.5907 - val_accuracy: 0.6984
# Epoch 4/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4684 - accuracy: 0.8571 - val_loss: 0.6595 - val_accuracy: 0.7302
# Epoch 5/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.2503 - accuracy: 0.9592 - val_loss: 0.3805 - val_accuracy: 0.8254
# Epoch 6/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0933 - accuracy: 0.9932 - val_loss: 0.5345 - val_accuracy: 0.8413
# Epoch 7/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0637 - accuracy: 0.9932 - val_loss: 0.4472 - val_accuracy: 0.8254
# Epoch 8/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0491 - accuracy: 0.9932 - val_loss: 0.6995 - val_accuracy: 0.7143
# Epoch 9/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0258 - accuracy: 1.0000 - val_loss: 0.4461 - val_accuracy: 0.7778
# Epoch 10/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.6063 - val_accuracy: 0.7302
# Epoch 11/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.3874 - val_accuracy: 0.7778
# Epoch 12/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.3165 - val_accuracy: 0.8413
# Epoch 13/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4328 - val_accuracy: 0.7937
# Epoch 14/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5719 - val_accuracy: 0.7778
# Epoch 15/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.4498 - val_accuracy: 0.8254
# Epoch 16/100
# 5/5 [==============================] - 0s 49ms/step - loss: 9.4424e-04 - accuracy: 1.0000 - val_loss: 0.3851 - val_accuracy: 0.8730
# Epoch 17/100
# 5/5 [==============================] - 0s 61ms/step - loss: 8.3335e-04 - accuracy: 1.0000 - val_loss: 0.4100 - val_accuracy: 0.8413
# Epoch 18/100
# 5/5 [==============================] - 0s 62ms/step - loss: 6.4900e-04 - accuracy: 1.0000 - val_loss: 0.4623 - val_accuracy: 0.8254
# Epoch 19/100
# 5/5 [==============================] - 0s 64ms/step - loss: 5.4774e-04 - accuracy: 1.0000 - val_loss: 0.4691 - val_accuracy: 0.8254
# Epoch 20/100
# 5/5 [==============================] - 0s 61ms/step - loss: 4.8153e-04 - accuracy: 1.0000 - val_loss: 0.4528 - val_accuracy: 0.8254
# Epoch 21/100
# 5/5 [==============================] - 0s 55ms/step - loss: 4.0818e-04 - accuracy: 1.0000 - val_loss: 0.4286 - val_accuracy: 0.8413
# Epoch 22/100
# 5/5 [==============================] - 0s 57ms/step - loss: 3.7124e-04 - accuracy: 1.0000 - val_loss: 0.4163 - val_accuracy: 0.8413
# Epoch 23/100
# 5/5 [==============================] - 0s 60ms/step - loss: 3.3403e-04 - accuracy: 1.0000 - val_loss: 0.4143 - val_accuracy: 0.8413
# Epoch 24/100
# 5/5 [==============================] - 0s 54ms/step - loss: 3.0934e-04 - accuracy: 1.0000 - val_loss: 0.4229 - val_accuracy: 0.8413
# Epoch 25/100
# 5/5 [==============================] - 0s 64ms/step - loss: 2.7647e-04 - accuracy: 1.0000 - val_loss: 0.4342 - val_accuracy: 0.8413
# Epoch 26/100
# 5/5 [==============================] - 0s 64ms/step - loss: 2.5943e-04 - accuracy: 1.0000 - val_loss: 0.4471 - val_accuracy: 0.8254
# Score for fold 2: loss of 0.27816927433013916; accuracy of 90.27777910232544%
# Epoch 1/100
# 5/5 [==============================] - 2s 98ms/step - loss: 2.9449 - accuracy: 0.3946 - val_loss: 0.5452 - val_accuracy: 0.7143
# Epoch 2/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.7828 - accuracy: 0.6190 - val_loss: 0.6979 - val_accuracy: 0.6032
# Epoch 3/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.5651 - accuracy: 0.7551 - val_loss: 0.6392 - val_accuracy: 0.6984
# Epoch 4/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.5523 - accuracy: 0.7551 - val_loss: 0.5776 - val_accuracy: 0.6190
# Epoch 5/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.3983 - accuracy: 0.8844 - val_loss: 0.5044 - val_accuracy: 0.8254
# Epoch 6/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2306 - accuracy: 0.9660 - val_loss: 0.4423 - val_accuracy: 0.8413
# Epoch 7/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1651 - accuracy: 0.9456 - val_loss: 0.5415 - val_accuracy: 0.7619
# Epoch 8/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.1072 - accuracy: 1.0000 - val_loss: 0.5147 - val_accuracy: 0.7302
# Epoch 9/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0753 - accuracy: 1.0000 - val_loss: 0.5913 - val_accuracy: 0.7143
# Epoch 10/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0371 - accuracy: 1.0000 - val_loss: 0.4643 - val_accuracy: 0.8413
# Epoch 11/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0229 - accuracy: 1.0000 - val_loss: 0.5068 - val_accuracy: 0.8095
# Epoch 12/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.4452 - val_accuracy: 0.8413
# Epoch 13/100
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.5090 - val_accuracy: 0.8095
# Epoch 14/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5027 - val_accuracy: 0.8095
# Epoch 15/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.5528 - val_accuracy: 0.7937
# Epoch 16/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.4585 - val_accuracy: 0.8413
# Score for fold 3: loss of 0.10351777076721191; accuracy of 97.22222089767456%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.11683857440948486 - Accuracy: 94.52054500579834%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.27816927433013916 - Accuracy: 90.27777910232544%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.10351777076721191 - Accuracy: 97.22222089767456%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 94.00684833526611 (+- 2.8582315236564084)
# > Loss: 0.16617520650227866
# ------------------------------------------------------------------------

# %%
#Evaluation con test dataset
model.evaluate(Test, Test_Labels)
# Out:
# 1/1 [==============================] - 0s 182ms/step - loss: 0.5256 - accuracy: 0.8571
# [0.5255853533744812, 0.8571428656578064]

# %%
#Plot di accuracy e validation accuracy
pd.DataFrame(history.history)[["accuracy","val_accuracy"]].plot()
# Out:
# <Axes: >

# %%
#Plot loss e validation loss
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
# Out:
# <Axes: >

# %%
#Confusion Matrix
predict= model.predict(inputs)
predict1 = tf.argmax(predict, axis=1)
confusion_matrix(targets,predict1)
# Out:
# 7/7 [==============================] - 0s 62ms/step
# array([[69,  1,  5],
#        [ 1, 74,  1],
#        [ 3,  0, 63]])

# %%
ConfusionMatrixDisplay.from_predictions(targets, predict1,display_labels=Classes)

# %%
def plot_wrong_labeled_data(X_test, y_true, y_preds, label_to_check, wrong_label = None):
  # Search for the wrong data
  wrongs = []
  for i in range(len(X_test)):
    true_label_found = y_true[i] == label_to_check
    wrong_label_found = wrong_label != None and y_preds[i] == wrong_label
    wrong_preds_label = wrong_label == None and y_preds[i] != label_to_check
    if true_label_found and (wrong_label_found or wrong_preds_label):
      wrongs.append((X_test[i], y_preds[i]))
  
  # Shuffle result
  random.shuffle(wrongs)

  # Plot result
  plt.figure(figsize=(10,10))
  for i in range(3):
    wrong = wrongs[i]
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(wrong[0], cmap=plt.cm.binary)
    plt.text(14, 32, wrong[1].numpy())
  plt.show()

# %%
#Plot immagini con wrong label
plot_wrong_labeled_data(inputs, targets, predict1,0,2)
