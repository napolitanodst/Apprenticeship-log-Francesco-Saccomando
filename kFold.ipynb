# %% [markdown]
# <a href="https://colab.research.google.com/github/napolitanodst/Apprenticeship-log/blob/Apprenticeship-Code/kFold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt
import pickle
import zipfile
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.losses import sparse_categorical_crossentropy
from tensorflow.keras.optimizers import Adam

# %%
#Importing delle immagini del dataset
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/dataset.zip', 'r') 
zip_ref.extractall('/tmp') 
zip_ref.close()

# %%
Dir= '/tmp/dataset'
Classes= ['Metamorfiche','Sedimentarie', 'Vulcaniche']

# %%
data = []
for category in Classes:
    folder = os.path.join(Dir, category)
    label = Classes.index(category)
    for img in os.listdir(folder):
        percorso = os.path.join(folder, img)
        array = cv2.imread(percorso)
        array= cv2.resize(array,(384,306))
        data.append([array,label])
random.shuffle(data)

# %%
#Creazione Dataset
Train_data = []
Train_labels = []
for features, labels in data:
  Train_data.append(features)
  Train_labels.append(labels)

Data = np.array(Train_data)
Labels = np.array(Train_labels)

# %%
#Creazione Test Dataset
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/test.zip', 'r') 
zip_ref.extractall('/tmp') 
zip_ref.close()

cartella = '/tmp/test'
Test= []
for category in Classes:
    folder2 = os.path.join(cartella, category)
    label = Classes.index(category)
    for img in os.listdir(folder2):
        percorso2 = os.path.join(folder2, img)
        array2 = cv2.imread(percorso2)
        array2= cv2.resize(array2,(384,306))
        Test.append([array2,label])
random.shuffle(Test)     

Test_data = []
Test_labels = []
for features, labels in Test:
  Test_data.append(features)
  Test_labels.append(labels)

Test = np.array(Test_data)
Test_Labels = np.array(Test_labels)

# %%
#Early Stopping per monitorare la validation accuracy
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_accuracy',patience=10, mode="auto")

# %%
# K-fold Cross Validation model evaluation
n_folders = 3
kfold = KFold(n_splits=n_folders, shuffle=True)
folder_accuracy = []
folder_loss = []
inputs = np.concatenate((Data,Test), axis=0)
targets = np.concatenate((Labels,Test_Labels), axis=0)

fold_no=1
for train, test in kfold.split(inputs, targets):
    model = tf.keras.models.Sequential(  
        [
        tf.keras.layers.Rescaling(1./255),   
        tf.keras.layers.Conv2D(16, 4, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(7, 4, activation ='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(100, activation='relu'),
        tf.keras.layers.Dense(len(Classes), activation="softmax")
        ]
    )
    training=model.compile(
             optimizer=tf.keras.optimizers.Adam(),
             loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             metrics=["accuracy"]
    )
    history = model.fit(
                    Data,
                    Labels,
                    validation_split = 0.3,
                    epochs=100,
                    callbacks= [early_stopping]
    ) 
    scores = model.evaluate(inputs[test], targets[test], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    folder_accuracy.append(scores[1] * 100)
    folder_loss.append(scores[0])

    fold_no = fold_no + 1

print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(folder_accuracy)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {folder_loss[i]} - Accuracy: {folder_accuracy[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(folder_accuracy)} (+- {np.std(folder_accuracy)})')
print(f'> Loss: {np.mean(folder_loss)}')
print('------------------------------------------------------------------------')
# Out:
# Epoch 1/100
# 5/5 [==============================] - 14s 411ms/step - loss: 6.7609 - accuracy: 0.3878 - val_loss: 7.4550 - val_accuracy: 0.2698
# Epoch 2/100
# 5/5 [==============================] - 0s 57ms/step - loss: 3.0643 - accuracy: 0.3741 - val_loss: 0.8684 - val_accuracy: 0.6825
# Epoch 3/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.9080 - accuracy: 0.6531 - val_loss: 0.8964 - val_accuracy: 0.6667
# Epoch 4/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.8966 - accuracy: 0.5646 - val_loss: 0.8969 - val_accuracy: 0.5556
# Epoch 5/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.8106 - accuracy: 0.6735 - val_loss: 0.8527 - val_accuracy: 0.6349
# Epoch 6/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.6884 - accuracy: 0.6939 - val_loss: 0.6507 - val_accuracy: 0.6825
# Epoch 7/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.5294 - accuracy: 0.7823 - val_loss: 0.5247 - val_accuracy: 0.7302
# Epoch 8/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.4535 - accuracy: 0.8027 - val_loss: 0.6515 - val_accuracy: 0.6667
# Epoch 9/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4038 - accuracy: 0.8163 - val_loss: 0.5595 - val_accuracy: 0.6984
# Epoch 10/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.3044 - accuracy: 0.9456 - val_loss: 0.5060 - val_accuracy: 0.7619
# Epoch 11/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2523 - accuracy: 0.9388 - val_loss: 0.6856 - val_accuracy: 0.7302
# Epoch 12/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.2378 - accuracy: 0.9524 - val_loss: 0.5346 - val_accuracy: 0.7143
# Epoch 13/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.1873 - accuracy: 0.9388 - val_loss: 0.5867 - val_accuracy: 0.7460
# Epoch 14/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1378 - accuracy: 0.9728 - val_loss: 0.6919 - val_accuracy: 0.7143
# Epoch 15/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1178 - accuracy: 0.9592 - val_loss: 0.5105 - val_accuracy: 0.7937
# Epoch 16/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0725 - accuracy: 0.9864 - val_loss: 0.7211 - val_accuracy: 0.7143
# Epoch 17/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0575 - accuracy: 0.9932 - val_loss: 0.5774 - val_accuracy: 0.7778
# Epoch 18/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0427 - accuracy: 0.9932 - val_loss: 0.7005 - val_accuracy: 0.7619
# Epoch 19/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0321 - accuracy: 0.9932 - val_loss: 0.6990 - val_accuracy: 0.8095
# Epoch 20/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0245 - accuracy: 0.9932 - val_loss: 0.7044 - val_accuracy: 0.7619
# Epoch 21/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0209 - accuracy: 1.0000 - val_loss: 0.6509 - val_accuracy: 0.7937
# Epoch 22/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.7314 - val_accuracy: 0.7778
# Epoch 23/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0130 - accuracy: 1.0000 - val_loss: 0.7489 - val_accuracy: 0.7937
# Epoch 24/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.7192 - val_accuracy: 0.7937
# Epoch 25/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0090 - accuracy: 1.0000 - val_loss: 0.7242 - val_accuracy: 0.7619
# Epoch 26/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.7338 - val_accuracy: 0.8095
# Epoch 27/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.7870 - val_accuracy: 0.7619
# Epoch 28/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.7656 - val_accuracy: 0.7937
# Epoch 29/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.7613 - val_accuracy: 0.7937
# Score for fold 1: loss of 0.3018879294395447; accuracy of 89.99999761581421%
# Epoch 1/100
# 5/5 [==============================] - 2s 88ms/step - loss: 3.3364 - accuracy: 0.3537 - val_loss: 1.6035 - val_accuracy: 0.5397
# Epoch 2/100
# 5/5 [==============================] - 0s 56ms/step - loss: 1.2380 - accuracy: 0.5510 - val_loss: 0.7181 - val_accuracy: 0.5556
# Epoch 3/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.8508 - accuracy: 0.4626 - val_loss: 0.7597 - val_accuracy: 0.6032
# Epoch 4/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.8503 - accuracy: 0.6122 - val_loss: 0.7362 - val_accuracy: 0.6349
# Epoch 5/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.8005 - accuracy: 0.6531 - val_loss: 0.6884 - val_accuracy: 0.6508
# Epoch 6/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.7473 - accuracy: 0.7891 - val_loss: 0.6873 - val_accuracy: 0.7143
# Epoch 7/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.6858 - accuracy: 0.9184 - val_loss: 0.6577 - val_accuracy: 0.6984
# Epoch 8/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.6200 - accuracy: 0.9116 - val_loss: 0.6638 - val_accuracy: 0.7460
# Epoch 9/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.5359 - accuracy: 0.9184 - val_loss: 0.6551 - val_accuracy: 0.7143
# Epoch 10/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.3899 - accuracy: 0.9320 - val_loss: 0.6477 - val_accuracy: 0.6825
# Epoch 11/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.2551 - accuracy: 0.8844 - val_loss: 0.6903 - val_accuracy: 0.6984
# Epoch 12/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.2095 - accuracy: 0.9252 - val_loss: 0.6288 - val_accuracy: 0.6984
# Epoch 13/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.2666 - accuracy: 0.9048 - val_loss: 0.7959 - val_accuracy: 0.7143
# Epoch 14/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.3394 - accuracy: 0.9456 - val_loss: 0.6573 - val_accuracy: 0.6667
# Epoch 15/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.3513 - accuracy: 0.9456 - val_loss: 0.6858 - val_accuracy: 0.6190
# Epoch 16/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.1966 - accuracy: 0.9592 - val_loss: 0.5130 - val_accuracy: 0.6825
# Epoch 17/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1412 - accuracy: 0.9864 - val_loss: 0.6361 - val_accuracy: 0.6984
# Epoch 18/100
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0904 - accuracy: 0.9864 - val_loss: 0.7604 - val_accuracy: 0.7619
# Epoch 19/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0458 - accuracy: 1.0000 - val_loss: 0.6127 - val_accuracy: 0.7460
# Epoch 20/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0333 - accuracy: 0.9864 - val_loss: 0.6053 - val_accuracy: 0.7778
# Epoch 21/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.6079 - val_accuracy: 0.7778
# Epoch 22/100
# 5/5 [==============================] - 0s 63ms/step - loss: 0.0120 - accuracy: 1.0000 - val_loss: 0.6917 - val_accuracy: 0.8095
# Epoch 23/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.7109 - val_accuracy: 0.7937
# Epoch 24/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.7077 - val_accuracy: 0.7778
# Epoch 25/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.6665 - val_accuracy: 0.7619
# Epoch 26/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.6359 - val_accuracy: 0.7937
# Epoch 27/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.6210 - val_accuracy: 0.7778
# Epoch 28/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.6190 - val_accuracy: 0.7460
# Epoch 29/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.6000 - val_accuracy: 0.7937
# Epoch 30/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.6167 - val_accuracy: 0.7619
# Epoch 31/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5975 - val_accuracy: 0.7778
# Epoch 32/100
# 5/5 [==============================] - 0s 50ms/step - loss: 7.3335e-04 - accuracy: 1.0000 - val_loss: 0.5566 - val_accuracy: 0.7619
# Score for fold 2: loss of 1.5400348901748657; accuracy of 83.74999761581421%
# Epoch 1/100
# 5/5 [==============================] - 2s 115ms/step - loss: 2.7033 - accuracy: 0.2381 - val_loss: 1.2132 - val_accuracy: 0.5556
# Epoch 2/100
# 5/5 [==============================] - 0s 57ms/step - loss: 1.1055 - accuracy: 0.5306 - val_loss: 1.0754 - val_accuracy: 0.3016
# Epoch 3/100
# 5/5 [==============================] - 0s 51ms/step - loss: 1.0140 - accuracy: 0.6735 - val_loss: 1.0235 - val_accuracy: 0.6190
# Epoch 4/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.8561 - accuracy: 0.8163 - val_loss: 0.8401 - val_accuracy: 0.6508
# Epoch 5/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.4707 - accuracy: 0.9320 - val_loss: 0.5138 - val_accuracy: 0.7619
# Epoch 6/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2350 - accuracy: 0.9116 - val_loss: 0.7066 - val_accuracy: 0.6508
# Epoch 7/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.1001 - accuracy: 0.9796 - val_loss: 0.4876 - val_accuracy: 0.7460
# Epoch 8/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0746 - accuracy: 1.0000 - val_loss: 1.2890 - val_accuracy: 0.5873
# Epoch 9/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0318 - accuracy: 1.0000 - val_loss: 0.4288 - val_accuracy: 0.7619
# Epoch 10/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0167 - accuracy: 1.0000 - val_loss: 0.5865 - val_accuracy: 0.7619
# Epoch 11/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.9863 - val_accuracy: 0.6984
# Epoch 12/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.7505 - val_accuracy: 0.7143
# Epoch 13/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5532 - val_accuracy: 0.7302
# Epoch 14/100
# 5/5 [==============================] - 0s 59ms/step - loss: 9.2083e-04 - accuracy: 1.0000 - val_loss: 0.5423 - val_accuracy: 0.7302
# Epoch 15/100
# 5/5 [==============================] - 0s 59ms/step - loss: 6.0499e-04 - accuracy: 1.0000 - val_loss: 0.5641 - val_accuracy: 0.7302
# Score for fold 3: loss of 0.4124850630760193; accuracy of 89.87341523170471%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.3018879294395447 - Accuracy: 89.99999761581421%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 1.5400348901748657 - Accuracy: 83.74999761581421%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.4124850630760193 - Accuracy: 89.87341523170471%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 87.87447015444438 (+- 2.9169003029960296)
# > Loss: 0.7514692942301432
# ------------------------------------------------------------------------

# %%
#Evaluation con test dataset
model.evaluate(Test, Test_Labels)
# Out:
# 1/1 [==============================] - 0s 323ms/step - loss: 3.4839 - accuracy: 0.4828
# [3.483881711959839, 0.48275861144065857]

# %%
#Plot di accuracy e validation accuracy
pd.DataFrame(history.history)[["accuracy","val_accuracy"]].plot()
# Out:
# <Axes: >

# %%
#Plot loss e validation loss
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
# Out:
# <Axes: >

# %%
#Confusion Matrix
predict= model.predict(inputs)
predict1 = tf.argmax(predict, axis=1)
confusion_matrix(targets,predict1)
# Out:
# 8/8 [==============================] - 0s 12ms/step
# array([[68,  0, 10],
#        [ 4, 78,  5],
#        [ 5,  8, 61]])

# %%
ConfusionMatrixDisplay.from_predictions(targets, predict1)

# %%
def plot_wrong_labeled_data(X_test, y_true, y_preds, label_to_check, wrong_label = None):
  # Search for the wrong data
  wrongs = []
  for i in range(len(X_test)):
    true_label_found = y_true[i] == label_to_check
    wrong_label_found = wrong_label != None and y_preds[i] == wrong_label
    wrong_preds_label = wrong_label == None and y_preds[i] != label_to_check
    if true_label_found and (wrong_label_found or wrong_preds_label):
      wrongs.append((X_test[i], y_preds[i]))
  
  # Shuffle result
  random.shuffle(wrongs)

  # Plot result
  plt.figure(figsize=(10,10))
  for i in range(10):
    wrong = wrongs[i]
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(wrong[0], cmap=plt.cm.binary)
    plt.text(14, 32, wrong[1].numpy())
  plt.show()

# %%
#Plot immagini con wrong label
plot_wrong_labeled_data(inputs, targets, predict1,0,2)
