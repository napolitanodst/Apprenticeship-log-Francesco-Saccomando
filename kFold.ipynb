# %% [markdown]
# <a href="https://colab.research.google.com/github/napolitanodst/Apprenticeship-log/blob/Apprenticeship-Code/kFold.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
import os
import random
import matplotlib.pyplot as plt
import pickle
import zipfile
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold

# %%
#Importing delle immagini del dataset
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/dataset.zip', 'r') 
zip_ref.extractall('/tmp') 
zip_ref.close()

# %%
Dir= '/tmp/dataset'
Classes= ['Metamorfiche','Sedimentarie', 'Vulcaniche']

# %%
data = []
for category in Classes:
    folder = os.path.join(Dir, category)
    label = Classes.index(category)
    for img in os.listdir(folder):
        percorso = os.path.join(folder, img)
        array = cv2.imread(percorso)
        array= cv2.resize(array,(384,306))
        data.append([array,label])
random.shuffle(data)

# %%
#Creazione Dataset
Train_data = []
Train_labels = []
for features, labels in data:
  Train_data.append(features)
  Train_labels.append(labels)

Data = np.array(Train_data)
Labels = np.array(Train_labels)

# %%
#Creazione Test Dataset
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/test.zip', 'r') 
zip_ref.extractall('/tmp') 
zip_ref.close()

cartella = '/tmp/test'
Test= []
for category in Classes:
    folder2 = os.path.join(cartella, category)
    label = Classes.index(category)
    for img in os.listdir(folder2):
        percorso2 = os.path.join(folder2, img)
        array2 = cv2.imread(percorso2)
        array2= cv2.resize(array2,(384,306))
        Test.append([array2,label])
random.shuffle(Test)     

Test_data = []
Test_labels = []
for features, labels in Test:
  Test_data.append(features)
  Test_labels.append(labels)

Test = np.array(Test_data)
Test_Labels = np.array(Test_labels)

# %%
#Early Stopping per monitorare la validation accuracy
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_accuracy',patience=10, mode="auto")

# %%
# K-fold Cross Validation model evaluation
n_folders = 3
kfold = KFold(n_splits=n_folders, shuffle=True)
folder_accuracy = []
folder_loss = []
inputs = np.concatenate((Data,Test), axis=0)
targets = np.concatenate((Labels,Test_Labels), axis=0)

fold_no=1
for train, test in kfold.split(inputs, targets):
    model = tf.keras.models.Sequential(  
        [
        tf.keras.layers.Rescaling(1./255),   
        tf.keras.layers.Conv2D(16, 4, activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(7, 4, activation ='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(100, activation='relu'),
        tf.keras.layers.Dense(len(Classes), activation="softmax")
        ]
    )
    training=model.compile(
             optimizer=tf.keras.optimizers.Adam(),
             loss=tf.keras.losses.SparseCategoricalCrossentropy(),
             metrics=["accuracy"]
    )
    history = model.fit(
                    Data,
                    Labels,
                    validation_split = 0.3,
                    epochs=100,
                    callbacks= [early_stopping]
    ) 
    scores = model.evaluate(inputs[test], targets[test], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    folder_accuracy.append(scores[1] * 100)
    folder_loss.append(scores[0])

    fold_no = fold_no + 1

print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(folder_accuracy)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {folder_loss[i]} - Accuracy: {folder_accuracy[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(folder_accuracy)} (+- {np.std(folder_accuracy)})')
print(f'> Loss: {np.mean(folder_loss)}')
print('------------------------------------------------------------------------')
# Out:
# Epoch 1/100
# 5/5 [==============================] - 14s 311ms/step - loss: 2.4847 - accuracy: 0.5102 - val_loss: 0.9350 - val_accuracy: 0.6349
# Epoch 2/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.8408 - accuracy: 0.6667 - val_loss: 0.8495 - val_accuracy: 0.6190
# Epoch 3/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.8107 - accuracy: 0.6259 - val_loss: 0.7491 - val_accuracy: 0.6984
# Epoch 4/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.7140 - accuracy: 0.6735 - val_loss: 0.6336 - val_accuracy: 0.6984
# Epoch 5/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.5546 - accuracy: 0.7347 - val_loss: 0.5740 - val_accuracy: 0.7302
# Epoch 6/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4466 - accuracy: 0.8639 - val_loss: 0.5532 - val_accuracy: 0.6667
# Epoch 7/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.3218 - accuracy: 0.9048 - val_loss: 0.5571 - val_accuracy: 0.6825
# Epoch 8/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.2087 - accuracy: 0.9252 - val_loss: 0.5602 - val_accuracy: 0.6825
# Epoch 9/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1504 - accuracy: 0.9864 - val_loss: 0.4930 - val_accuracy: 0.8095
# Epoch 10/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.1016 - accuracy: 1.0000 - val_loss: 0.5246 - val_accuracy: 0.8095
# Epoch 11/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0582 - accuracy: 1.0000 - val_loss: 0.5236 - val_accuracy: 0.7937
# Epoch 12/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0493 - accuracy: 0.9932 - val_loss: 0.5558 - val_accuracy: 0.8095
# Epoch 13/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0300 - accuracy: 1.0000 - val_loss: 0.5607 - val_accuracy: 0.8413
# Epoch 14/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0243 - accuracy: 1.0000 - val_loss: 0.5396 - val_accuracy: 0.8413
# Epoch 15/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.6277 - val_accuracy: 0.8095
# Epoch 16/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.5522 - val_accuracy: 0.8254
# Epoch 17/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0124 - accuracy: 1.0000 - val_loss: 0.5659 - val_accuracy: 0.7937
# Epoch 18/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0092 - accuracy: 1.0000 - val_loss: 0.6555 - val_accuracy: 0.8095
# Epoch 19/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.5606 - val_accuracy: 0.8413
# Epoch 20/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0075 - accuracy: 1.0000 - val_loss: 0.6012 - val_accuracy: 0.8254
# Epoch 21/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.6142 - val_accuracy: 0.8254
# Epoch 22/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0047 - accuracy: 1.0000 - val_loss: 0.5660 - val_accuracy: 0.8254
# Epoch 23/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.6137 - val_accuracy: 0.8254
# Score for fold 1: loss of 1.61591374874115; accuracy of 88.7499988079071%
# Epoch 1/100
# 5/5 [==============================] - 2s 124ms/step - loss: 18.9876 - accuracy: 0.3129 - val_loss: 4.8013 - val_accuracy: 0.4444
# Epoch 2/100
# 5/5 [==============================] - 0s 52ms/step - loss: 5.5738 - accuracy: 0.4898 - val_loss: 1.9998 - val_accuracy: 0.4762
# Epoch 3/100
# 5/5 [==============================] - 0s 51ms/step - loss: 1.3231 - accuracy: 0.5306 - val_loss: 1.0444 - val_accuracy: 0.4762
# Epoch 4/100
# 5/5 [==============================] - 0s 51ms/step - loss: 1.0140 - accuracy: 0.4014 - val_loss: 0.9316 - val_accuracy: 0.4603
# Epoch 5/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.9870 - accuracy: 0.3401 - val_loss: 0.8948 - val_accuracy: 0.4603
# Epoch 6/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.9423 - accuracy: 0.3810 - val_loss: 0.9505 - val_accuracy: 0.4921
# Epoch 7/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.9100 - accuracy: 0.4286 - val_loss: 0.8440 - val_accuracy: 0.4603
# Epoch 8/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.8702 - accuracy: 0.3673 - val_loss: 0.8115 - val_accuracy: 0.4762
# Epoch 9/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.8212 - accuracy: 0.5306 - val_loss: 0.8037 - val_accuracy: 0.5556
# Epoch 10/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.7846 - accuracy: 0.6190 - val_loss: 0.7879 - val_accuracy: 0.4921
# Epoch 11/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.7456 - accuracy: 0.6122 - val_loss: 0.7870 - val_accuracy: 0.5873
# Epoch 12/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.7021 - accuracy: 0.7755 - val_loss: 0.8047 - val_accuracy: 0.4921
# Epoch 13/100
# 5/5 [==============================] - 0s 56ms/step - loss: 0.6245 - accuracy: 0.7823 - val_loss: 0.9029 - val_accuracy: 0.6190
# Epoch 14/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.5745 - accuracy: 0.8367 - val_loss: 0.8786 - val_accuracy: 0.5079
# Epoch 15/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.4929 - accuracy: 0.9116 - val_loss: 0.8865 - val_accuracy: 0.5397
# Epoch 16/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.4272 - accuracy: 0.9320 - val_loss: 0.9294 - val_accuracy: 0.5714
# Epoch 17/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.3579 - accuracy: 0.9524 - val_loss: 0.9586 - val_accuracy: 0.5238
# Epoch 18/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.3039 - accuracy: 0.9456 - val_loss: 1.0636 - val_accuracy: 0.6032
# Epoch 19/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2559 - accuracy: 0.9592 - val_loss: 1.0641 - val_accuracy: 0.5556
# Epoch 20/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.2133 - accuracy: 0.9796 - val_loss: 1.1148 - val_accuracy: 0.5397
# Epoch 21/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.1927 - accuracy: 0.9728 - val_loss: 1.1383 - val_accuracy: 0.5714
# Epoch 22/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.1467 - accuracy: 0.9864 - val_loss: 1.1258 - val_accuracy: 0.5714
# Epoch 23/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.1159 - accuracy: 0.9932 - val_loss: 1.2445 - val_accuracy: 0.6190
# Score for fold 2: loss of 0.5691907405853271; accuracy of 81.25%
# Epoch 1/100
# 5/5 [==============================] - 3s 133ms/step - loss: 2.7979 - accuracy: 0.3129 - val_loss: 1.1645 - val_accuracy: 0.2698
# Epoch 2/100
# 5/5 [==============================] - 0s 53ms/step - loss: 0.9580 - accuracy: 0.4966 - val_loss: 0.6495 - val_accuracy: 0.6349
# Epoch 3/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.6566 - accuracy: 0.6599 - val_loss: 0.5745 - val_accuracy: 0.6508
# Epoch 4/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.5766 - accuracy: 0.6871 - val_loss: 1.0023 - val_accuracy: 0.6190
# Epoch 5/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.7395 - accuracy: 0.6735 - val_loss: 0.8791 - val_accuracy: 0.5714
# Epoch 6/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.5800 - accuracy: 0.7347 - val_loss: 0.6640 - val_accuracy: 0.7302
# Epoch 7/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.4529 - accuracy: 0.9456 - val_loss: 0.5687 - val_accuracy: 0.6667
# Epoch 8/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.2329 - accuracy: 0.9592 - val_loss: 0.5175 - val_accuracy: 0.7778
# Epoch 9/100
# 5/5 [==============================] - 0s 49ms/step - loss: 0.1476 - accuracy: 0.9592 - val_loss: 0.6542 - val_accuracy: 0.7302
# Epoch 10/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.1076 - accuracy: 0.9728 - val_loss: 0.5412 - val_accuracy: 0.8254
# Epoch 11/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0638 - accuracy: 0.9932 - val_loss: 0.8726 - val_accuracy: 0.6984
# Epoch 12/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0417 - accuracy: 0.9932 - val_loss: 0.5991 - val_accuracy: 0.7778
# Epoch 13/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0354 - accuracy: 0.9932 - val_loss: 0.9541 - val_accuracy: 0.6984
# Epoch 14/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0324 - accuracy: 0.9932 - val_loss: 0.5064 - val_accuracy: 0.8571
# Epoch 15/100
# 5/5 [==============================] - 0s 59ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.7552 - val_accuracy: 0.7460
# Epoch 16/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0222 - accuracy: 0.9932 - val_loss: 0.5922 - val_accuracy: 0.8254
# Epoch 17/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.6548 - val_accuracy: 0.7460
# Epoch 18/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.8547 - val_accuracy: 0.7619
# Epoch 19/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.6212 - val_accuracy: 0.8254
# Epoch 20/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5964 - val_accuracy: 0.8254
# Epoch 21/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.5887 - val_accuracy: 0.8095
# Epoch 22/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.5523 - val_accuracy: 0.8413
# Epoch 23/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5335 - val_accuracy: 0.8571
# Epoch 24/100
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5468 - val_accuracy: 0.8413
# Score for fold 3: loss of 0.19602708518505096; accuracy of 91.13923907279968%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 1.61591374874115 - Accuracy: 88.7499988079071%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.5691907405853271 - Accuracy: 81.25%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.19602708518505096 - Accuracy: 91.13923907279968%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 87.04641262690227 (+- 4.21314741943439)
# > Loss: 0.793710524837176
# ------------------------------------------------------------------------

# %%
#Evaluation con test dataset
model.evaluate(Test, Test_Labels)
# Out:
# 1/1 [==============================] - 0s 318ms/step - loss: 4.4080 - accuracy: 0.3448
# [4.408040523529053, 0.3448275923728943]

# %%
#Plot di accuracy e validation accuracy
pd.DataFrame(history.history)[["accuracy","val_accuracy"]].plot()
# Out:
# <Axes: >

# %%
#Plot loss e validation loss
pd.DataFrame(history.history)[["loss", "val_loss"]].plot()
# Out:
# <Axes: >

# %%
#Confusion Matrix
predict= model.predict(inputs)
predict1 = tf.argmax(predict, axis=1)
confusion_matrix(targets,predict1)
# Out:
# 8/8 [==============================] - 0s 13ms/step
# array([[67,  1, 10],
#        [ 0, 80,  7],
#        [ 5,  6, 63]])

# %%
ConfusionMatrixDisplay.from_predictions(targets, predict1)

# %%
def plot_wrong_labeled_data(X_test, y_true, y_preds, label_to_check, wrong_label = None):
  # Search for the wrong data
  wrongs = []
  for i in range(len(X_test)):
    true_label_found = y_true[i] == label_to_check
    wrong_label_found = wrong_label != None and y_preds[i] == wrong_label
    wrong_preds_label = wrong_label == None and y_preds[i] != label_to_check
    if true_label_found and (wrong_label_found or wrong_preds_label):
      wrongs.append((X_test[i], y_preds[i]))
  
  # Shuffle result
  random.shuffle(wrongs)

  # Plot result
  plt.figure(figsize=(10,10))
  for i in range(10):
    wrong = wrongs[i]
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(wrong[0], cmap=plt.cm.binary)
    plt.text(14, 32, wrong[1].numpy())
  plt.show()

# %%
#Plot immagini con wrong label
plot_wrong_labeled_data(inputs, targets, predict1,0,2)
